# %%
""" Enunciado
Una empresa del sector tecnológico quiere estimar el salario mensual de sus empleados en función de
distintas variables relacionadas con su perfil profesional. Para ello, se dispone de un conjunto de datos
históricos que será utilizado para construir un modelo de regresión lineal.
Herramienta

Anaconda (Jupyter Notebook).

Conjunto de datos
Se proporciona un fichero llamado empleados.csv que contiene las siguientes variables:
edad → Edad del empleado (años)
experiencia → Años de experiencia laboral
formacion → Nivel formativo (1 = FP, 2 = Grado, 3 = Máster)
horas_extra → Número medio de horas extra mensuales
salario → Salario mensual en euros (variable dependiente)
Se pide

Estudiar el proceso completo de creación de un modelo de regresión lineal.
Aplicar técnicas básicas de análisis exploratorio de datos.
Construir y evaluar un modelo predictivo.
Interpretar los coeficientes obtenidos.
Tareas a realizar

1. Carga y exploración de datos
Importa las librerías necesarias (pandas, numpy, matplotlib, sklearn).
Carga el fichero empleados.csv.
Muestra las primeras filas del conjunto de datos.
Comprueba si existen valores nulos o inconsistencias.

2. Análisis exploratorio
Calcula estadísticas descriptivas básicas.
Representa gráficamente la relación entre las variables independientes y el salario.
Comenta brevemente qué variables parecen tener mayor relación con el salario.

3. Preparación de los datos
Separa las variables independientes (X) y la variable dependiente (y).
Divide el conjunto de datos en conjunto de entrenamiento y de prueba (por ejemplo, 80 % / 20 %).
Justifica brevemente por qué es necesaria esta división.

4. Construcción del modelo
Crea un modelo de regresión lineal.
Entrena el modelo con los datos de entrenamiento.
Muestra la ecuación del modelo obtenido.

5. Evaluación del modelo
Realiza predicciones sobre el conjunto de prueba.
Calcula al menos una métrica de evaluación (R², MAE o MSE).
Interpreta el resultado obtenido.

6. Interpretación
Explica qué significado tienen los coeficientes del modelo.
Indica qué variable tiene mayor impacto en el salario según el modelo.
Comenta una posible limitación del modelo construido.
"""
# Out:
# ' Enunciado\nUna empresa del sector tecnológico quiere estimar el salario mensual de sus empleados en función de\ndistintas variables relacionadas con su perfil profesional. Para ello, se dispone de un conjunto de datos\nhistóricos que será utilizado para construir un modelo de regresión lineal.\nHerramienta\n\nAnaconda (Jupyter Notebook).\n\nConjunto de datos\nSe proporciona un fichero llamado empleados.csv que contiene las siguientes variables:\nedad → Edad del empleado (años)\nexperiencia → Años de experiencia laboral\nformacion → Nivel formativo (1 = FP, 2 = Grado, 3 = Máster)\nhoras_extra → Número medio de horas extra mensuales\nsalario → Salario mensual en euros (variable dependiente)\nSe pide\n\nEstudiar el proceso completo de creación de un modelo de regresión lineal.\nAplicar técnicas básicas de análisis exploratorio de datos.\nConstruir y evaluar un modelo predictivo.\nInterpretar los coeficientes obtenidos.\nTareas a realizar\n\n1. Carga y exploración de datos\nImporta las librerías necesarias (pandas, numpy, matplotlib, sklearn).\nCarga el fichero empleados.csv.\nMuestra las primeras filas del conjunto de datos.\nComprueba si existen valores nulos o inconsistencias.\n\n2. Análisis exploratorio\nCalcula estadísticas descriptivas básicas.\nRepresenta gráficamente la relación entre las variables independientes y el salario.\nComenta brevemente qué variables parecen tener mayor relación con el salario.\n\n3. Preparación de los datos\nSepara las variables independientes (X) y la variable dependiente (y).\nDivide el conjunto de datos en conjunto de entrenamiento y de prueba (por ejemplo, 80 % / 20 %).\nJustifica brevemente por qué es necesaria esta división.\n\n4. Construcción del modelo\nCrea un modelo de regresión lineal.\nEntrena el modelo con los datos de entrenamiento.\nMuestra la ecuación del modelo obtenido.\n\n5. Evaluación del modelo\nRealiza predicciones sobre el conjunto de prueba.\nCalcula al menos una métrica de evaluación (R², MAE o MSE).\nInterpreta el resultado obtenido.\n\n6. Interpretación\nExplica qué significado tienen los coeficientes del modelo.\nIndica qué variable tiene mayor impacto en el salario según el modelo.\nComenta una posible limitación del modelo construido.\n'

# %%
"""1. Carga y exploración de datos
Importa las librerías necesarias (pandas, numpy, matplotlib, sklearn).
Carga el fichero empleados.csv.
Muestra las primeras filas del conjunto de datos.
Comprueba si existen valores nulos o inconsistencias.
"""

import pandas as pd

dfFires = pd.read_csv("fires-all.csv")[0:1000]

dfFires.sort_values(by=['superficie'], ascending=True, inplace=True)

dfFires.head(20)
# Out:
#              id  superficie       fecha  lat  lng  latlng_explicit  \
# 996  1968241245         1.0  1968-08-25  NaN  NaN              NaN
# 46   1968080109         1.0  1968-02-05  NaN  NaN              NaN
# 74   1968390101         1.0  1968-02-22  NaN  NaN              NaN
# 889  1968471122         1.0  1968-08-19  NaN  NaN              NaN
# 872  1968491412         1.0  1968-08-17  NaN  NaN              NaN
# 869  1968281079         1.0  1968-08-17  NaN  NaN              NaN
# 95   1968320122         1.0  1968-03-07  NaN  NaN              NaN
# 91   1968320121         1.0  1968-03-06  NaN  NaN              NaN
# 401  1968070545         1.0  1968-06-30  NaN  NaN              NaN
# 402  1968080523         1.0  1968-06-30  NaN  NaN              NaN
# 468  1968390772         1.0  1968-07-10  NaN  NaN              NaN
# 463  1968330811         1.0  1968-07-09  NaN  NaN              NaN
# 509  1968330837         1.0  1968-07-16  NaN  NaN              NaN
# 504  1968170688         1.0  1968-07-15  NaN  NaN              NaN
# 501  1968100739         1.0  1968-07-15  NaN  NaN              NaN
# 494  1968280705         1.0  1968-07-14  NaN  NaN              NaN
# 136  1968430174         1.0  1968-03-17  NaN  NaN              NaN
# 112  1968360134         1.0  1968-03-13  NaN  NaN              NaN
# 117  1968080306         1.0  1968-03-14  NaN  NaN              NaN
# 126  1968470167         1.0  1968-03-15  NaN  NaN              NaN
#
#      idcomunidad  idprovincia  idmunicipio      municipio  ...  \
# 996           17           24            0  INDETERMINADO  ...
# 46             2            8            0  INDETERMINADO  ...
# 74             6           39            0  INDETERMINADO  ...
# 889           17           47            0  INDETERMINADO  ...
# 872           17           49            0  INDETERMINADO  ...
# 869           16           28            0  INDETERMINADO  ...
# 95             3           32            0  INDETERMINADO  ...
# 91             3           32            0  INDETERMINADO  ...
# 401           15            7            0  INDETERMINADO  ...
# 402            2            8            0  INDETERMINADO  ...
# 468            6           39            0  INDETERMINADO  ...
# 463            5           33            0  INDETERMINADO  ...
# 509            5           33            0  INDETERMINADO  ...
# 504            2           17            0  INDETERMINADO  ...
# 501           14           10            0  INDETERMINADO  ...
# 494           16           28            0  INDETERMINADO  ...
# 136            2           43            0  INDETERMINADO  ...
# 112            3           36            0  INDETERMINADO  ...
# 117            2            8            0  INDETERMINADO  ...
# 126           17           47            0  INDETERMINADO  ...
#
#      causa_supuesta  causa_desc  muertos  heridos  time_ctrl  time_ext  \
# 996               1           0        0        0          0       120
# 46                1           0        0        0          0       180
# 74                1          99        0        0          0      1500
# 889               1          50        0        0          0       120
# 872               1          50        0        0          0       300
# 869               1          50        0        0          0        60
# 95                1           0        0        0          0        60
# 91                1           0        0        0          0        60
# 401               1          50        0        0          0       120
# 402               1          40        0        0          0       120
# 468               1          99        0        0          0       120
# 463               1           0        0        0          0       180
# 509               1           0        0        0          0       480
# 504               1          50        0        0          0       480
# 501               1          40        0        0          0        60
# 494               1          40        0        0          0        60
# 136               1          40        0        0          0       420
# 112               1           0        0        0          0        60
# 117               1           0        0        0          0       120
# 126               1           0        0        0          0       120
#
#      personal  medios  gastos  perdidas
# 996         0       0       0         0
# 46          0       0       0         0
# 74          0       0       0         0
# 889         0       0      18         0
# 872         0       0       0         0
# 869         0       0       0         0
# 95          0       0       0         0
# 91          0       0       0         0
# 401         0       0       0         0
# 402         0       0       0         0
# 468         0       0       0         0
# 463         0       0       0         0
# 509         0       0       0         0
# 504         0       0       0         0
# 501         0       0       0         0
# 494         0       0       0         0
# 136         0       0       0         0
# 112         0       0       0         0
# 117         0       0       0         0
# 126         0       0       0         0
#
# [20 rows x 21 columns]

# %%
"""3. Preparación de los datos
Separa las variables independientes (X) y la variable dependiente (y). y:salario X: edad, experiencia, formacion, horas_extra
Divide el conjunto de datos en conjunto de entrenamiento y de prueba (por ejemplo, 80 % / 20 %).
Justifica brevemente por qué es necesaria esta división."""

import matplotlib.pyplot as plt

plt.scatter(dfFires['personal'],dfFires['superficie'])
plt.title("Grafico de superficie por heridos")
plt.xlabel("personal implicado")
plt.ylabel("superficie")
plt.show()

# %%
"""3. Preparación de los datos
Separa las variables independientes (X) y la variable dependiente (y).
Divide el conjunto de datos en conjunto de entrenamiento y de prueba (por ejemplo, 80 % / 20 %).
Justifica brevemente por qué es necesaria esta división."""


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

x = dfFires[['superficie','personal','perdidas','gastos']]
y = dfFires['superficie']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state = 42
)

# %%
"""4. Construcción del modelo
Crea un modelo de regresión lineal.
Entrena el modelo con los datos de entrenamiento.
Muestra la ecuación del modelo obtenido."""

model = LinearRegression()
model.fit(x_train, y_train)

pd.DataFrame({
    'Variable' : x.columns,
    'Coeficiente' : model.coef_
})
# Out:
#      Variable   Coeficiente
# 0  superficie  1.000000e+00
# 1    personal -8.041814e-17
# 2    perdidas  9.589920e-17
# 3      gastos  3.747875e-16

# %%
"""5. Evaluación del modelo
Realiza predicciones sobre el conjunto de prueba.
Calcula al menos una métrica de evaluación (R2, MAE o MSE).
Interpreta el resultado obtenido."""

y_pred = model.predict(x_test)

print("R2:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2: 1.0
# MAE: 3.4755531785890527e-14
# MSE: 8.294994445320216e-27

# %%
"""6. Interpretación
Explica qué significado tienen los coeficientes del modelo.
Indica qué variable tiene mayor impacto en el salario según el modelo.
Comenta una posible limitación del modelo construido."""
# Out:
# '6. Interpretación\nExplica qué significado tienen los coeficientes del modelo.\nIndica qué variable tiene mayor impacto en el salario según el modelo.\nComenta una posible limitación del modelo construido.'
